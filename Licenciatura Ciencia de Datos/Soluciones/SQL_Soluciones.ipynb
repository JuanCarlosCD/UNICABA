# %% [markdown]
# # Soluciones

# %%
# Ejercicio 1ventas = [12000, 15000, 13000, 12500, 14000, 15500]print(ventas)

# %%
# Ejercicio 2total = sum(ventas)promedio = total / len(ventas)print(total, promedio)

# %%
# Ejercicio 3import matplotlib.pyplot as pltmeses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio']plt.plot(meses, ventas)plt.show()

# %%
# Ejercicio 4precios = [250, 300, 150, 200, 180]promedio_precio = sum(precios) / len(precios)superan = sum(1 for p in precios if p > promedio_precio)print(superan)
