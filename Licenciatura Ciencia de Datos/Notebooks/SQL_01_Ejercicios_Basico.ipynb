# %% [markdown]
# # Licenciatura en Ciencia de Datos## Universidad de la Ciudad de Buenos AiresCurso: Introducción a Python para Análisis de Datos

# %% [markdown]
# ### 📖 IntroducciónPython en Ciencia de Datos: análisis, visualización, modelado, automatización.

# %% [markdown]
# ### 💡 Tips Generales- Usar `print()`- Ejecutar por partes- Revisar errores

# %% [markdown]
# ## 🧩 Ejercicio 1: Crear una lista

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 2: Operaciones básicas

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 3: Gráfico simple

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 4: Desafío extra

# %%
# --- TU CÓDIGO AQUÍ ---
