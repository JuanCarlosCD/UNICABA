# %% [markdown]
# # Licenciatura en Ciencia de Datos## Universidad de la Ciudad de Buenos AiresCurso: Introducción a Python para Análisis de Datos

# %% [markdown]
# ### 📖 IntroducciónAnálisis exploratorio de datos con groupby, nuevas columnas y visualizaciones.

# %% [markdown]
# ### 💡 Tips- `groupby()`- Nuevas columnas

# %% [markdown]
# ## 🧩 Ejercicio 1: Explorar dataset

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 2: Nuevas columnas

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 3: Agrupar y analizar

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 4: Visualizaciones

# %%
# --- TU CÓDIGO AQUÍ ---
