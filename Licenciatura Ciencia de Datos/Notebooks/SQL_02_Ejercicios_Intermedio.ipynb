# %% [markdown]
# # Licenciatura en Ciencia de Datos## Universidad de la Ciudad de Buenos AiresCurso: Introducción a Python para Análisis de Datos

# %% [markdown]
# ### 📖 IntroducciónDataFrames y pandas: manipulación de datos tabulares.

# %% [markdown]
# ### 💡 Tips- `df.head()`- Eliminar nulos

# %% [markdown]
# ## 🧩 Ejercicio 1: Leer CSV

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 2: Limpiar datos

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 3: Estadísticas

# %%
# --- TU CÓDIGO AQUÍ ---

# %% [markdown]
# ## 🧩 Ejercicio 4: Gráficos

# %%
# --- TU CÓDIGO AQUÍ ---
